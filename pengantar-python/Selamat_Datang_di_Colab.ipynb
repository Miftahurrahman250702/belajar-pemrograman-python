# %% [markdown]
# <a href="https://colab.research.google.com/github/Miftahurrahman250702/belajar-pemrograman-python/blob/main/pengantar-python/Selamat_Datang_di_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# latihan mendeklarasikan variabel

x = 20  #contoh deklarasi dan inisialisasi variabel
y = 30
hasil = x + y #melakulakukan operasi pada kedua variabel

print (hasil, type(hasil))
# Out:
# 50 <class 'int'>
